# %%
from simul7_plot_multicycle import plot_single_cycle_result

# %%
plot_single_cycle_result('./datafiles/x3dc_00006.pkl')
# Out:
# ...
#  File: ./datafiles/x3dc_00006.pkl
# ...
#
# running inside a Notebook (Jupyter or otherwise)...
# TODO: print simulation parameters used
#
# -------------------------
# Brownian analysis summary
# -------------------------
# D_guess (user): 0.11299999999999999 µm2/s
# D_guess (refined): 0.10372636108225003 µm2/s
# q_low:  0.10833078115826873 µm-1
# q_opt:  0.18957886702697027 µm-1
# q_high: 0.5687366010809108 µm-1
# D (fit): 0.09973672751994798 µm2/s (+/-  0.004051235699563229 , 95% CI)

# %% [markdown]
# ## TO DO
#
# - Read a single cycle result without plotting
# - Separate reading of results and plotting, such that the data from the results is available at the command line for further analysis
