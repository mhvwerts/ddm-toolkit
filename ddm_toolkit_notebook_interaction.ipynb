# %%
from time import sleep

# %%
# the following does not work if we do the ddm_toolkit import first

# %%
# %run simul1_simulate_synthesize.py
# Out:
# running inside a Notebook (Jupyter or otherwise)...
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
from ddm_toolkit import isnotebook

# %%
isnotebook()
# Out:
# True

# %%
# %run tests/test_6_test_utility_functions.py
# Out:
# isnotebook():  True

# %%
from ddm_toolkit import tqdm

# %%
for i in tqdm(range(10)):
    sleep(1)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
# %run simul3_calculate_ISF.py
# Out:
# *** using ImageStructureEngine (the original) ***
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
# %run simul5_analyze.py
# Out:
# WARNING: B-to-A ratio exceeded before iq_high.
#          stopping the analysis here. updating iq_high to reflect last valid point
# D_guess (user): 1.1 µm2/s
# D_guess (refined): 0.09013592656559039 µm2/s
# q_low:  0.3249923434748062 µm-1
# q_opt:  0.6770673822391796 µm-1
# q_high: 1.0020597257139858 µm-1
# q_max:  3.439502301775032 µm-1
# D (fit): 0.09731047382211934 µm2/s (+/-  0.0028352164462713187 , 95% CI)
# (close all open child windows to terminate script)
